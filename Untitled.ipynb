# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv(r"C:\Users\HP\Downloads\teleCust1000t.csv")

# %%
train_data.head(5)
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3

# %%
## Data visualization and Data analysis
train_data['custcat'].value_counts()
# Out:
# custcat
# 3    281
# 1    266
# 4    236
# 2    217
# Name: count, dtype: int64

# %%
train_data.hist(column = 'income',bins=50)
# Out:
# array([[<Axes: title={'center': 'income'}>]], dtype=object)

# %%
## filling the missing values
import os
import sys
sys.path.append(r"C:\Users\HP\Linear Regression\Customer segmentation using knn\src")

# %%
from preprocessing import clean_data

# %%
train_data = clean_data(train_data)

# %%
train_data.head(5)
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3

# %%
from train_model import full_train_pipeline

# %%
train_acc,test_acc,mean_acc,std_acc = full_train_pipeline(train_data)
# Out:
# The best accuracy was with 0.35 with k= 9

# %%
train_acc
# Out:
# 0.4875

# %%
test_acc
# Out:
# 0.315

# %%
mean_acc
# Out:
# array([0.29 , 0.3  , 0.325, 0.305, 0.335, 0.325, 0.345, 0.315, 0.35 ])

# %%
std_acc
# Out:
# array([0.03208582, 0.0324037 , 0.0331191 , 0.03255572, 0.03337477,
#        0.0331191 , 0.03361361, 0.03284623, 0.03372684])
