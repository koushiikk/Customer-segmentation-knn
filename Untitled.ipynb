# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv(r"C:\Users\HP\Downloads\teleCust1000t.csv")

# %%
train_data.head(5)
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3

# %%
## Data visualization and Data analysis
train_data['custcat'].value_counts()
# Out:
# custcat
# 3    281
# 1    266
# 4    236
# 2    217
# Name: count, dtype: int64

# %%
train_data.hist(column = 'income',bins=50)
# Out:
# array([[<Axes: title={'center': 'income'}>]], dtype=object)

# %%
## filling the missing values
import os
import sys
sys.path.append(r"C:\Users\HP\Linear Regression\Customer segmentation using knn\src")

# %%
from preprocessing import clean_data

# %%
train_data = clean_data(train_data)

# %%
train_data.head(5)
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3

# %%
from train_model import full_train_pipeline

# %%
train_acc, test_acc, mean_acc, std_acc, best_k = full_train_pipeline(train_data)
# Out:
# Confusion Matrix:
#  [[29  7 10  3]
#  [ 9 11 13 10]
#  [18  8 24  4]
#  [21  3 16 14]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            1       0.38      0.59      0.46        49
#            2       0.38      0.26      0.31        43
#            3       0.38      0.44      0.41        54
#            4       0.45      0.26      0.33        54
#
#     accuracy                           0.39       200
#    macro avg       0.40      0.39      0.38       200
# weighted avg       0.40      0.39      0.38       200
# C:\Users\HP\Linear Regression\Customer segmentation using knn\src\train_model.py:77: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='gender', data=df, palette='Set2')
# The best accuracy was with 0.39 with k= 36

# %%
test_acc
# Out:
# 0.305

# %%
mean_acc
# Out:
# array([0.265, 0.28 , 0.315, 0.295, 0.36 , 0.355, 0.325, 0.32 , 0.325,
#        0.305, 0.315, 0.33 , 0.32 , 0.315, 0.295, 0.305, 0.315, 0.305,
#        0.33 , 0.325, 0.31 , 0.34 , 0.355, 0.355, 0.345, 0.345, 0.36 ,
#        0.345, 0.375, 0.36 , 0.375, 0.385, 0.38 , 0.385, 0.37 , 0.39 ,
#        0.375, 0.38 , 0.36 ])

# %%
std_acc
# Out:
# array([0.03120697, 0.03174902, 0.03284623, 0.03224709, 0.03394113,
#        0.033836  , 0.0331191 , 0.03298485, 0.0331191 , 0.03255572,
#        0.03284623, 0.03324906, 0.03298485, 0.03284623, 0.03224709,
#        0.03255572, 0.03284623, 0.03255572, 0.03324906, 0.0331191 ,
#        0.03270321, 0.03349627, 0.033836  , 0.033836  , 0.03361361,
#        0.03361361, 0.03394113, 0.03361361, 0.03423266, 0.03394113,
#        0.03423266, 0.03440748, 0.034322  , 0.03440748, 0.03413942,
#        0.03448913, 0.03423266, 0.034322  , 0.03394113])

# %%
best_k
# Out:
# np.int64(36)
